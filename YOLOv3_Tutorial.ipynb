# %%
# clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 14163 (delta 5), reused 12 (delta 5), pack-reused 14148
# Receiving objects: 100% (14163/14163), 12.77 MiB | 23.56 MiB/s, done.
# Resolving deltas: 100% (9622/9622), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# make darknet (build)
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ./src/image_opencv.cpp:1130:10: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#           if (iteration_old != 0){
#           ^~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1424:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ./src/image_opencv.cpp:1400:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#      int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1404:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#      int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1408:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#      int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1411:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#      int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#          ^~~~~~~~~
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# In file included from ./src/http_stream.cpp:580:0:
# ./src/httplib.h:129:0: warning: "INVALID_SOCKET" redefined
#  #define INVALID_SOCKET (-1)
#
# ./src/http_stream.cpp:73:0: note: this is the location of the previous definition
#  #define INVALID_SOCKET -1
#
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:249:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:507:113: warning: format ‘%zu’ expects argument of type ‘size_t’, but argument 3 has type ‘int’ [-Wformat=]
#                  sprintf(head, "--mjpegstream\r\nContent-Type: image/jpeg\r\nContent-Length: %zu\r\n\r\n", outlen);
#                                                                                                                  ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:845:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < v.size(); ++i) {
#                          ~~^~~~~~~~~~
# ./src/http_stream.cpp:853:33: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int old_id = 0; old_id < old_dets.size(); ++old_id) {
#                           ~~~~~~~^~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:873:31: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int index = 0; index < new_dets_num*old_dets.size(); ++index) {
#                          ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:908:28: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      if (old_dets_dq.size() > deque_size) old_dets_dq.pop_front();
#          ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2038:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2037:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘custom_hash’:
# ./src/utils.c:1040:12: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#      while (c = *str++)
#             ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘cudnn_check_error_extended’:
# ./src/dark_cuda.c:224:20: warning: comparison between ‘cudaError_t {aka enum cudaError}’ and ‘enum <anonymous>’ [-Wenum-compare]
#          if (status != CUDNN_STATUS_SUCCESS)
#                     ^~
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:276:40: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                       ~~^
#                                       %Ilu
#              size / (1024*1024), num_of_blocks, pinned_block_size / (1024 * 1024));
#              ~~~~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:276:64: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                               ~~^
#                                                               %Ilu
# ./src/dark_cuda.c:276:82: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                                                 ~~^
#                                                                                 %Ilu
# ./src/dark_cuda.c:286:37: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#                  printf(" Allocated %d pinned block \n", pinned_block_size);
#                                     ~^
#                                     %ld
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:307:43: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#              printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#                                           ~^
#                                           %ld
# ./src/dark_cuda.c:322:64: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#                                                                ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                                %ld
# ./src/dark_cuda.c:328:63: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#                                                               ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                               %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1337:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:79:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:79:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:310:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:310:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:310:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#                  int out_index = id;
#                      ^~~~~~~~~
# ./src/blas.c: In function ‘find_sim’:
# ./src/blas.c:597:59: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                           ~^
#                                                           %ld
# ./src/blas.c:597:67: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                   ~^
#                                                                   %ld
# ./src/blas.c:597:75: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                           ~^
#                                                                           %ld
# ./src/blas.c: In function ‘find_P_constrastive’:
# ./src/blas.c:611:68: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                    ~^
#                                                                    %ld
# ./src/blas.c:611:76: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                            ~^
#                                                                            %ld
# ./src/blas.c:611:84: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                                    ~^
#                                                                                    %ld
# ./src/blas.c: In function ‘P_constrastive_f’:
# ./src/blas.c:651:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:651:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# ./src/blas.c: In function ‘P_constrastive’:
# ./src/blas.c:780:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:780:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/softmax_layer.c -o obj/softmax_layer.o
# ./src/softmax_layer.c: In function ‘make_contrastive_layer’:
# ./src/softmax_layer.c:202:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 9 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#      fprintf(stderr, "contrastive %4d x%4d x%4d x emb_size %4d x batch: %4d  classes = %4d, step = %4d \n", w, h, l.n, l.embedding_size, batch, l.classes, step);
#                                                                                                    ~~^
#                                                                                                    %4ld
# ./src/softmax_layer.c: In function ‘forward_contrastive_layer’:
# ./src/softmax_layer.c:243:27: warning: variable ‘max_truth’ set but not used [-Wunused-but-set-variable]
#                      float max_truth = 0;
#                            ^~~~~~~~~
# ./src/softmax_layer.c:420:71: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#              printf(" Error: too large number of bboxes: contr_size = %d > max_contr_size  = %d \n", contr_size, max_contr_size);
#                                                                       ~^
#                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1294:24: warning: unused variable ‘x’ [-Wunused-variable]
#                  int k, x, y;
#                         ^
# ./src/data.c:1090:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#      float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#                                            ^~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:615:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:346:11: warning: unused variable ‘one’ [-Wunused-variable]
#      float one = 1;    // alpha[0], beta[0]
#            ^~~
# ./src/connected_layer.c:344:13: warning: unused variable ‘c’ [-Wunused-variable]
#      float * c = l.output_gpu;
#              ^
# ./src/connected_layer.c:343:13: warning: unused variable ‘b’ [-Wunused-variable]
#      float * b = l.weights_gpu;
#              ^
# ./src/connected_layer.c:342:13: warning: unused variable ‘a’ [-Wunused-variable]
#      float * a = state.input;
#              ^
# ./src/connected_layer.c:341:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = l.outputs;
#          ^
# ./src/connected_layer.c:340:9: warning: unused variable ‘k’ [-Wunused-variable]
#      int k = l.inputs;
#          ^
# ./src/connected_layer.c:339:9: warning: unused variable ‘m’ [-Wunused-variable]
#      int m = l.batch;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1652:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/parser.c: In function ‘get_classes_multipliers’:
# ./src/parser.c:418:29: warning: argument 1 range [18446744071562067968, 18446744073709551615] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#          classes_multipliers = (float *)calloc(classes_counters, sizeof(float));
#          ~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./src/parser.c:3:0:
# /usr/include/stdlib.h:541:14: note: in a call to allocation function ‘calloc’ declared here
#  extern void *calloc (size_t __nmemb, size_t __size)
#               ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#      switch(iou_kind) {
#      ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#                      float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#                      float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#      char *base = "results/comp4_det_test_";
#            ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘print_cocos’:
# ./src/detector.c:477:29: warning: format not a string literal and no format arguments [-Wformat-security]
#                  fprintf(fp, buff);
#                              ^~~~
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:570:21: warning: statement with no effect [-Wunused-value]
#                      for (k; buf[k + n] != '\0'; k++)
#                      ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:691:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#          int mkd2 = make_directory(buff2, 0777);
#              ^~~~
# ./src/detector.c:689:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#          int mkd = make_directory(buff, 0777);
#              ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1322:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1321:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1856:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#              float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#                    ^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:204:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#      if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#                                                    ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:146:9: warning: unused variable ‘count’ [-Wunused-variable]
#      int count = 0;
#          ^~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:855:13: warning: unused variable ‘time’ [-Wunused-variable]
#      clock_t time;
#              ^~~~
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1287:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                                  ^~~~~~~~~~~
# ./src/classifier.c:1287:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                      ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#          float scale = sqrt(2. / l.nweights);
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘detect_in_thread’:
# ./src/demo.c:100:16: warning: unused variable ‘prediction’ [-Wunused-variable]
#          float *prediction = network_predict(net, X);
#                 ^~~~~~~~~~
# ./src/demo.c:98:15: warning: unused variable ‘l’ [-Wunused-variable]
#          layer l = net.layers[net.n - 1];
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:59:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#      int old_h = l->h;
#          ^~~~~
# ./src/region_layer.c:58:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#      int old_w = l->w;
#          ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:66:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:73:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:103:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:112:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘forward_yolo_layer’:
# ./src/yolo_layer.c:390:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#                      int best_match_t = 0;
#                          ^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gaussian_yolo_layer.c -o obj/gaussian_yolo_layer.o
# ./src/gaussian_yolo_layer.c: In function ‘make_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:71:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:78:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:110:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:119:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# ./src/convolutional_kernels.cu: In function ‘void backward_convolutional_layer_gpu(convolutional_layer, network_state)’:
# ./src/convolutional_kernels.cu:845:40: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#                  if (*state.net.max_output16_size < l.nweights) {
#                  ~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu: In function ‘void backward_shortcut_multilayer_gpu(int, int, int, int*, float**, float*, float*, float*, float*, int, float*, float**, WEIGHTS_NORMALIZATION_T)’:
# ./src/blas_kernels.cu:1130:5: warning: variable ‘step’ set but not used [-Wunused-but-set-variable]
#      int step = 0;
#      ^~~~
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/network_kernels.cu -o obj/network_kernels.o
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu: In function ‘float train_network_datum_gpu(network, float*, float*)’:
# ./src/network_kernels.cu:364:7: warning: variable ‘l’ set but not used [-Wunused-but-set-variable]
#          layer l = net.layers[net.n - 1];
#        ^
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++

# %%
# get yolov3 pretrained coco dataset weights
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-08-05 02:52:48--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   491KB/s    in 10m 30s
#
# 2020-08-05 03:03:20 (384 KB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# define helper functions
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# use this to upload files
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

# use this to download a file  
def download(path):
  from google.colab import files
  files.download(path)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# ln: failed to create symbolic link '/mydrive/My Drive': Operation not supported
# 'Colab Notebooks'   driving.zip   tiktok.zip

# %%
# upload the video of your choosing! (Feel free to use the same video I do, it is in the Github repository)
upload()

# %%
# !./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3.weights -dont_show driving.mp4 -i 0 -out_filename results.avi    ### pastikan output.mp4 itu nama file video mu
# Out:
# Streaming output truncated to the last 5000 lines.
# bicycle: 43% , motorbike: 28%
# car: 32%
# bicycle: 90%
# person: 97%
# person: 96%
# person: 95%
# person: 95%
# person: 60%
# person: 58%
# person: 35%
#
# FPS:36.9 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# traffic light: 38%
# motorbike: 80%
# motorbike: 80%
# motorbike: 75%
# motorbike: 71%
# motorbike: 60%
# motorbike: 44%
# motorbike: 42%
# motorbike: 32%
# car: 41%
# car: 31%
# car: 30%
# bicycle: 86%
# person: 99%
# person: 96%
# person: 92%
# person: 85%
# person: 66%
# person: 63%
# person: 42%
#
# FPS:36.8 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# motorbike: 72%
# motorbike: 71%
# motorbike: 68%
# motorbike: 59%
# motorbike: 50%
# bicycle: 32%
# bicycle: 28%
# motorbike: 35%
# car: 61%
# car: 53%
# bicycle: 61%
# person: 98%
# person: 96%
# person: 87%
# person: 85%
# person: 69%
# person: 66%
# person: 25%
#
# FPS:37.3 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# traffic light: 49%
# motorbike: 93%
# motorbike: 84%
# motorbike: 69%
# motorbike: 66%
# motorbike: 40%
# bicycle: 59% , motorbike: 27%
# car: 62%
# car: 36%
# person: 96%
# person: 95%
# person: 94%
# person: 81%
# person: 56%
#
# FPS:36.2 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# traffic light: 29%
# motorbike: 85%
# motorbike: 72%
# motorbike: 62%
# motorbike: 62%
# motorbike: 61%
# bicycle: 61%
# person: 29%
# motorbike: 29%
# car: 69%
# car: 62%
# bicycle: 76%
# person: 99%
# person: 97%
# person: 84%
# person: 75%
# person: 42%
# person: 32%
#
# FPS:35.7 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# traffic light: 29%
# motorbike: 91%
# motorbike: 73%
# motorbike: 69%
# motorbike: 69%
# motorbike: 59%
# motorbike: 56%
# person: 50%
# car: 53%
# car: 49%
# car: 31%
# car: 25%
# person: 99%
# person: 97%
# person: 92%
# person: 72%
#
# FPS:35.3 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# traffic light: 38%
# motorbike: 94%
# motorbike: 77%
# motorbike: 70%
# motorbike: 61%
# bicycle: 78%
# motorbike: 49%
# bicycle: 25% , motorbike: 39%
# car: 72%
# car: 62%
# car: 36%
# car: 33%
# person: 100%
# person: 97%
# person: 91%
# person: 76%
#
# FPS:35.1 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# traffic light: 35%
# motorbike: 93%
# motorbike: 71%
# bicycle: 43% , motorbike: 55%
# motorbike: 55%
# bicycle: 27% , motorbike: 52%
# bicycle: 30% , motorbike: 36%
# car: 73%
# car: 63%
# car: 33%
# person: 98%
# person: 96%
# person: 73%
# person: 68%
# person: 59%
#
# FPS:36.1 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# tvmonitor: 50%
# motorbike: 76%
# motorbike: 74%
# motorbike: 56%
# motorbike: 47%
# car: 67%
# car: 53%
# car: 39%
# car: 32%
# bicycle: 43%
# bicycle: 38%
# bicycle: 32%
# person: 98%
# person: 95%
# person: 89%
# person: 73%
#
# FPS:36.9 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# stop sign: 52%
# motorbike: 78%
# motorbike: 66%
# motorbike: 64%
# motorbike: 55%
# motorbike: 40%
# car: 42% , motorbike: 32%
# car: 28% , motorbike: 28%
# car: 72%
# car: 53%
# bicycle: 47%
# person: 98%
# person: 96%
# person: 93%
# person: 75%
# person: 25%
#
# FPS:37.2 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# stop sign: 59%
# motorbike: 74%
# person: 36% , motorbike: 61%
# bicycle: 28% , motorbike: 56%
# motorbike: 55%
# motorbike: 50%
# motorbike: 27%
# motorbike: 27%
# car: 84%
# car: 71%
# car: 60%
# bicycle: 57%
# person: 98%
# person: 97%
# person: 88%
# person: 88%
# person: 66%
# person: 53%
# person: 27%
#
# FPS:36.6 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# tvmonitor: 39%
# stop sign: 71%
# motorbike: 88%
# motorbike: 55%
# motorbike: 51%
# bicycle: 28% , motorbike: 44%
# car: 85%
# car: 66%
# car: 49%
# bicycle: 26%
# person: 97%
# person: 92%
# person: 92%
# person: 90%
# person: 35%
# person: 26%
#
# FPS:36.1 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# stop sign: 48%
# motorbike: 82%
# motorbike: 55%
# motorbike: 40%
# bicycle: 45% , motorbike: 29%
# car: 90%
# car: 51%
# car: 47%
# car: 43%
# car: 34%
# bicycle: 48%
# person: 99%
# person: 95%
# person: 92%
# person: 75%
# person: 28%
#
# FPS:35.4 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# stop sign: 25%
# traffic light: 33%
# motorbike: 80%
# motorbike: 66%
# motorbike: 52%
# motorbike: 51%
# bicycle: 55% , motorbike: 41%
# motorbike: 36%
# car: 88%
# car: 58%
# car: 38%
# car: 34%
# car: 32%
# car: 31%
# bicycle: 46%
# person: 99%
# person: 96%
# person: 96%
# person: 89%
# person: 27%
#
# FPS:35.3 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# stop sign: 26%
# traffic light: 26%
# motorbike: 64%
# motorbike: 55%
# motorbike: 35%
# bicycle: 28% , motorbike: 33%
# person: 64%
# car: 76%
# car: 50%
# car: 35%
# car: 32%
# bicycle: 79%
# bicycle: 27%
# person: 99%
# person: 96%
# person: 91%
# person: 30%
# person: 28%
#
# FPS:36.2 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# motorbike: 72%
# motorbike: 37%
# motorbike: 35%
# bicycle: 45% , motorbike: 31%
# motorbike: 29%
# car: 54%
# car: 85%
# car: 55%
# car: 47%
# car: 30%
# car: 27%
# person: 98%
# person: 96%
# person: 93%
# person: 83%
# person: 59%
#
# FPS:37.0 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# motorbike: 67%
# motorbike: 42%
# motorbike: 30%
# car: 75%
# car: 61%
# car: 56%
# car: 45%
# car: 38%
# car: 35%
# car: 27%
# person: 97%
# person: 96%
# person: 89%
# person: 67%
# person: 38%
#
# FPS:36.9 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# traffic light: 35%
# motorbike: 72%
# motorbike: 45%
# motorbike: 29%
# car: 80%
# car: 71%
# car: 57%
# car: 37%
# bicycle: 44%
# person: 98%
# person: 94%
# person: 89%
# person: 88%
# person: 51%
#
# FPS:36.3 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# traffic light: 26%
# motorbike: 60%
# motorbike: 37%
# bicycle: 28%
# car: 91%
# car: 84%
# car: 41%
# car: 25%
# bicycle: 67%
# person: 97%
# person: 96%
# person: 90%
# person: 65%
# person: 63%
#
# FPS:35.8 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# traffic light: 41%
# motorbike: 62%
# motorbike: 53%
# car: 86%
# car: 82%
# car: 54%
# car: 41%
# car: 28%
# car: 27%
# bicycle: 63%
# person: 98%
# person: 94%
# person: 93%
# person: 41%
#
# FPS:35.3 	 AVG_FPS:36.5
#
#  cvWriteFrame
# Objects:
#
# traffic light: 38%
# motorbike: 74%
# motorbike: 47%
# bicycle: 30% , motorbike: 47%
# person: 38%
# car: 90%
# car: 69%
# car: 63%
# car: 59%
# car: 55%
# car: 25%
# person: 97%
# person: 94%
# person: 93%
#
# FPS:35.1 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# suitcase: 27%
# traffic light: 43%
# motorbike: 74%
# motorbike: 35%
# motorbike: 33%
# car: 86%
# car: 63%
# car: 40%
# car: 38%
# car: 32%
# person: 95%
# person: 94%
# person: 92%
# person: 37%
#
# FPS:34.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 34%
# truck: 27%
# motorbike: 73%
# motorbike: 72%
# motorbike: 64%
# motorbike: 46%
# motorbike: 45%
# car: 84%
# car: 58%
# car: 47%
# car: 38%
# car: 38%
# car: 32%
# car: 30%
# person: 97%
# person: 96%
# person: 85%
#
# FPS:35.1 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 36%
# motorbike: 71%
# motorbike: 62%
# motorbike: 56%
# motorbike: 52%
# motorbike: 39%
# car: 63%
# car: 57%
# car: 40%
# car: 40%
# person: 98%
# person: 88%
# person: 85%
#
# FPS:36.0 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 46%
# car: 56% , truck: 28%
# motorbike: 58%
# bicycle: 45% , motorbike: 45%
# motorbike: 37%
# car: 69%
# car: 39%
# car: 35%
# person: 97%
# person: 96%
# person: 90%
# person: 68%
#
# FPS:36.8 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 42%
# motorbike: 59%
# bicycle: 29% , motorbike: 56%
# motorbike: 41%
# motorbike: 39%
# car: 74%
# car: 66%
# car: 50%
# car: 39%
# car: 31%
# person: 96%
# person: 88%
# person: 88%
# person: 69%
#
# FPS:37.2 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 52%
# car: 72% , truck: 25%
# motorbike: 85%
# motorbike: 75%
# motorbike: 64%
# motorbike: 63%
# motorbike: 43%
# car: 72%
# car: 44%
# person: 95%
# person: 94%
# person: 88%
# person: 66%
# person: 39%
#
# FPS:37.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 48%
# motorbike: 81%
# motorbike: 63%
# motorbike: 62%
# motorbike: 59%
# motorbike: 49%
# motorbike: 38%
# car: 74%
# car: 64%
# car: 47%
# car: 26%
# person: 97%
# person: 93%
# person: 91%
# person: 86%
#
# FPS:37.1 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 33%
# motorbike: 65%
# motorbike: 62%
# motorbike: 62%
# motorbike: 59%
# bicycle: 35%
# motorbike: 41%
# motorbike: 38%
# car: 71%
# car: 52%
# car: 45%
# person: 99%
# person: 82%
# person: 81%
# person: 80%
# person: 39%
#
# FPS:37.8 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 57%
# person: 38% , motorbike: 70%
# motorbike: 50%
# motorbike: 40%
# motorbike: 38%
# motorbike: 37%
# motorbike: 36%
# car: 61%
# car: 40%
# car: 29%
# person: 98%
# person: 82%
# person: 78%
# person: 57%
# person: 29%
#
# FPS:38.4 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# motorbike: 83%
# person: 36%
# motorbike: 61%
# motorbike: 56%
# motorbike: 51%
# car: 51%
# car: 28%
# car: 27%
# person: 96%
# person: 82%
# person: 80%
# person: 64%
#
# FPS:38.9 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 28%
# motorbike: 88%
# person: 26%
# motorbike: 61%
# motorbike: 60%
# motorbike: 59%
# car: 62%
# person: 96%
# person: 91%
# person: 72%
# person: 65%
# person: 41%
#
# FPS:38.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# motorbike: 89%
# motorbike: 61%
# motorbike: 43%
# motorbike: 42%
# motorbike: 40%
# car: 63%
# car: 61%
# person: 94%
# person: 90%
# person: 74%
# person: 72%
# person: 70%
# person: 52%
# person: 31%
# person: 27%
#
# FPS:38.3 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# car: 49% , truck: 26%
# motorbike: 75%
# motorbike: 63%
# motorbike: 63%
# car: 59%
# car: 58%
# car: 29%
# person: 93%
# person: 85%
# person: 76%
# person: 71%
# person: 33%
# person: 30%
# person: 27%
#
# FPS:37.8 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# motorbike: 66%
# motorbike: 59%
# motorbike: 57%
# motorbike: 40%
# car: 78%
# car: 67%
# car: 61%
# person: 96%
# person: 85%
# person: 72%
# person: 56%
# person: 31%
# person: 31%
#
# FPS:37.2 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# motorbike: 53%
# motorbike: 39%
# bicycle: 31%
# motorbike: 27%
# car: 76%
# car: 66%
# car: 65%
# car: 51%
# car: 28%
# person: 96%
# person: 88%
# person: 63%
# person: 29%
#
# FPS:37.3 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# motorbike: 69%
# motorbike: 38%
# bicycle: 40%
# car: 71%
# car: 70%
# car: 43%
# car: 40%
# person: 96%
# person: 87%
# person: 72%
# person: 51%
# person: 36%
#
# FPS:36.9 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# fire hydrant: 55%
# motorbike: 49%
# motorbike: 37%
# car: 73%
# car: 58%
# car: 54%
# car: 33%
# car: 32%
# car: 27%
# bicycle: 48%
# person: 96%
# person: 62%
# person: 60%
# person: 44%
# person: 29%
#
# FPS:36.5 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# motorbike: 44%
# car: 70%
# car: 66%
# car: 48%
# car: 27%
# bicycle: 51%
# person: 99%
# person: 75%
# person: 52%
# person: 50%
# person: 44%
# person: 30%
#
# FPS:36.0 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# motorbike: 73%
# car: 66%
# car: 60%
# car: 52%
# car: 44%
# bicycle: 39%
# bicycle: 34%
# person: 99%
# person: 94%
# person: 65%
# person: 56%
# person: 41%
#
# FPS:35.3 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# motorbike: 40%
# car: 56%
# car: 42%
# car: 41%
# person: 99%
# person: 93%
# person: 84%
# person: 29%
# person: 25%
#
# FPS:36.1 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# car: 57% , truck: 31%
# motorbike: 41%
# motorbike: 29%
# car: 45%
# car: 38%
# car: 31%
# bicycle: 36%
# person: 99%
# person: 61%
# person: 53%
# person: 31%
# person: 27%
#
# FPS:36.8 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# motorbike: 62%
# motorbike: 33%
# motorbike: 32%
# car: 55%
# car: 55%
# car: 41%
# person: 55% , bicycle: 38%
# person: 99%
# person: 60%
# person: 36%
# person: 31%
# person: 31%
# person: 28%
#
# FPS:36.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# motorbike: 36%
# motorbike: 29%
# car: 50%
# car: 40%
# car: 33%
# bicycle: 53%
# person: 99%
# person: 78%
# person: 48%
# person: 34%
# person: 34%
#
# FPS:36.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# truck: 34%
# motorbike: 26%
# car: 62%
# car: 51%
# car: 32%
# car: 26%
# person: 55% , bicycle: 35%
# person: 99%
# person: 84%
# person: 52%
# person: 42%
# person: 31%
# person: 26%
#
# FPS:36.5 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# truck: 36%
# motorbike: 49%
# motorbike: 30%
# bicycle: 29% , motorbike: 28%
# car: 47%
# car: 36%
# car: 29%
# car: 27%
# bicycle: 31%
# person: 98%
# person: 61%
# person: 59%
# person: 58%
# person: 43%
# person: 37%
# person: 25%
#
# FPS:36.2 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# truck: 30%
# motorbike: 33%
# car: 46%
# car: 41%
# car: 36%
# car: 27%
# bicycle: 28%
# person: 99%
# person: 66%
# person: 42%
# person: 31%
# person: 28%
#
# FPS:35.9 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 59%
# motorbike: 37%
# bicycle: 32% , motorbike: 27%
# car: 59%
# car: 37%
# car: 31%
# car: 30%
# car: 27%
# person: 99%
# person: 65%
# person: 59%
# person: 43%
# person: 37%
# person: 26%
#
# FPS:35.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 62%
# car: 52%
# car: 34%
# person: 55% , bicycle: 35%
# person: 99%
# person: 56%
# person: 33%
#
# FPS:35.3 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 72%
# car: 50%
# car: 49%
# car: 43%
# car: 30%
# bicycle: 56%
# bicycle: 31%
# person: 98%
# person: 64%
# person: 49%
#
# FPS:35.5 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 66%
# car: 39%
# car: 32%
# person: 58% , bicycle: 25%
# person: 99%
# person: 57%
# person: 51%
# person: 30%
#
# FPS:35.4 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 63%
# truck: 38%
# motorbike: 36%
# motorbike: 33%
# car: 30%
# bicycle: 38%
# person: 95%
# person: 44%
# person: 33%
#
# FPS:35.1 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 63%
# truck: 46%
# bus: 36%
# car: 33%
# person: 35% , bicycle: 35%
# bicycle: 32%
# person: 99%
# person: 41%
#
# FPS:34.9 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 58%
# bus: 30% , truck: 40%
# car: 45%
# car: 35%
# bicycle: 36%
# bicycle: 29%
# person: 95%
# person: 40%
# person: 37%
# person: 26%
#
# FPS:35.2 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 56%
# car: 32% , truck: 34%
# car: 44%
# car: 26%
# bicycle: 44%
# bicycle: 34%
# person: 92%
# person: 51%
# person: 43%
#
# FPS:34.9 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 49%
# truck: 32%
# car: 31%
# bicycle: 49%
# person: 82%
# person: 57%
# person: 46%
# person: 34%
#
# FPS:36.0 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# truck: 28%
# person: 34% , car: 32%
# car: 25%
# bicycle: 51%
# person: 74%
# person: 58%
# person: 57%
# person: 37%
#
# FPS:36.2 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 28%
# truck: 32%
# bicycle: 37% , motorbike: 30%
# person: 29% , car: 33%
# car: 26%
# bicycle: 54%
# person: 57%
# person: 54%
# person: 48%
#
# FPS:35.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 38%
# truck: 34%
# motorbike: 29%
# car: 37%
# bicycle: 51%
# person: 61%
# person: 58%
# person: 42%
# person: 36%
# person: 28%
#
# FPS:36.0 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 51%
# truck: 49%
# bicycle: 47%
# person: 89%
# person: 50%
# person: 30%
# person: 28%
# person: 27%
# person: 27%
#
# FPS:35.4 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 44%
# truck: 56%
# car: 39%
# bicycle: 42%
# person: 95%
# person: 45%
# person: 44%
#
# FPS:35.8 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 50%
# truck: 49%
# car: 34%
# car: 30%
# car: 25%
# bicycle: 43%
# person: 93%
# person: 67%
# person: 61%
# person: 45%
#
# FPS:35.2 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# truck: 43%
# car: 60%
# car: 28%
# bicycle: 63%
# bicycle: 62%
# person: 90%
# person: 79%
# person: 70%
# person: 56%
# person: 28%
#
# FPS:34.8 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# truck: 57%
# car: 48%
# bicycle: 35%
# person: 92%
# person: 75%
# person: 71%
# person: 51%
# person: 29%
#
# FPS:34.8 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# truck: 60%
# car: 43%
# car: 43%
# bicycle: 57%
# bicycle: 48%
# bicycle: 42%
# person: 90%
# person: 67%
# person: 60%
# person: 58%
# person: 27%
#
# FPS:34.9 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# truck: 58%
# car: 28%
# car: 59%
# bicycle: 71%
# bicycle: 32%
# bicycle: 31%
# bicycle: 30%
# person: 93%
# person: 80%
# person: 69%
# person: 66%
# person: 41%
#
# FPS:35.3 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 41% , handbag: 36%
# truck: 58%
# car: 51%
# bus: 34%
# car: 59%
# bicycle: 67%
# bicycle: 34%
# bicycle: 25%
# bicycle: 25%
# person: 87%
# person: 81%
# person: 52%
# person: 51%
# person: 40%
# person: 29%
#
# FPS:35.5 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 84%
# truck: 52%
# car: 26%
# car: 61%
# bicycle: 44%
# bicycle: 36%
# bicycle: 26%
# person: 92%
# person: 81%
# person: 74%
# person: 45%
# person: 44%
# person: 28%
# person: 26%
#
# FPS:35.0 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# truck: 29%
# car: 46%
# car: 35%
# bicycle: 34%
# person: 96%
# person: 85%
# person: 67%
# person: 64%
# person: 52%
# person: 30%
#
# FPS:35.4 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# car: 51%
# car: 25%
# bicycle: 55%
# bicycle: 46%
# bicycle: 35%
# person: 93%
# person: 81%
# person: 64%
# person: 60%
# person: 40%
#
# FPS:35.3 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# car: 67%
# bicycle: 70%
# bicycle: 39%
# bicycle: 27%
# person: 91%
# person: 78%
# person: 62%
# person: 49%
# person: 28%
# person: 28%
#
# FPS:34.6 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 44%
# motorbike: 57%
# car: 71%
# bicycle: 39%
# person: 93%
# person: 84%
# person: 66%
# person: 62%
# person: 50%
# person: 29%
#
# FPS:34.5 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 27%
# car: 64% , truck: 32%
# motorbike: 67%
# car: 27%
# bicycle: 49%
# bicycle: 37%
# bicycle: 25%
# person: 96%
# person: 84%
# person: 70%
# person: 65%
# person: 48%
# person: 36%
# person: 32%
#
# FPS:34.3 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 70%
# motorbike: 82%
# car: 62%
# bicycle: 54%
# person: 97%
# person: 84%
# person: 66%
# person: 66%
# person: 30%
# person: 26%
#
# FPS:34.6 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# motorbike: 67%
# car: 62%
# car: 28%
# bicycle: 55%
# bicycle: 42%
# person: 95%
# person: 88%
# person: 68%
# person: 46%
# person: 30%
#
# FPS:34.4 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 30%
# car: 62% , truck: 25%
# motorbike: 47%
# bicycle: 35%
# bicycle: 28%
# person: 91%
# person: 90%
# person: 80%
# person: 45%
# person: 29%
#
# FPS:34.8 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 41%
# motorbike: 81%
# car: 70%
# car: 58%
# car: 29%
# bicycle: 48%
# bicycle: 45%
# person: 98%
# person: 83%
# person: 79%
# person: 45%
#
# FPS:34.8 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 38%
# traffic light: 30%
# car: 63%
# car: 40%
# bicycle: 52%
# bicycle: 48%
# bicycle: 48%
# person: 98%
# person: 83%
# person: 79%
# person: 79%
# person: 40%
#
# FPS:34.6 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 26%
# car: 54%
# bicycle: 74%
# bicycle: 39%
# bicycle: 29%
# person: 99%
# person: 90%
# person: 84%
# person: 70%
#
# FPS:34.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 66%
# traffic light: 44%
# car: 77%
# car: 60%
# bicycle: 80%
# bicycle: 50%
# person: 98%
# person: 84%
# person: 81%
# person: 67%
# person: 62%
#
# FPS:34.0 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 33%
# car: 77%
# car: 71%
# bicycle: 86%
# bicycle: 37%
# bicycle: 31%
# person: 97%
# person: 87%
# person: 73%
# person: 70%
# person: 29%
#
# FPS:34.5 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 44%
# traffic light: 33%
# motorbike: 35%
# person: 83% , motorbike: 28%
# car: 75%
# car: 57%
# bicycle: 71%
# bicycle: 34%
# person: 95%
# person: 74%
# person: 46%
# person: 28%
#
# FPS:34.4 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 35%
# traffic light: 47%
# motorbike: 28%
# car: 71%
# car: 49%
# car: 47%
# bicycle: 88%
# person: 98%
# person: 80%
# person: 61%
# person: 37%
# person: 31%
#
# FPS:35.1 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 35%
# traffic light: 56%
# bicycle: 54% , motorbike: 33%
# car: 54%
# car: 50%
# person: 95%
# person: 76%
# person: 65%
# person: 56%
# person: 36%
#
# FPS:36.0 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 62%
# traffic light: 54%
# bus: 35%
# bicycle: 45% , motorbike: 57%
# car: 39%
# car: 27%
# person: 90%
# person: 79%
# person: 74%
# person: 68%
# person: 43%
#
# FPS:36.4 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 33%
# traffic light: 59%
# motorbike: 30%
# car: 55%
# car: 31%
# bicycle: 51%
# person: 97%
# person: 85%
# person: 82%
# person: 72%
#
# FPS:36.8 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 31%
# traffic light: 65%
# car: 51%
# car: 46%
# bicycle: 47%
# person: 94%
# person: 84%
# person: 80%
# person: 58%
# person: 31%
#
# FPS:37.4 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 61%
# traffic light: 45%
# motorbike: 31%
# person: 83% , motorbike: 26%
# car: 58%
# car: 36%
# person: 90%
# person: 70%
# person: 30%
#
# FPS:37.9 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 27%
# traffic light: 27%
# motorbike: 48%
# motorbike: 44%
# person: 73% , motorbike: 40%
# car: 58%
# person: 26% , car: 27%
# person: 97%
# person: 66%
# person: 49%
# person: 30%
# person: 27%
#
# FPS:38.3 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 34%
# traffic light: 32%
# motorbike: 52%
# person: 64% , motorbike: 50%
# motorbike: 39%
# car: 33%
# car: 33%
# person: 98%
# person: 44%
# person: 33%
# person: 28%
#
# FPS:38.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 37%
# motorbike: 77%
# person: 81% , motorbike: 43%
# motorbike: 38%
# person: 35% , motorbike: 28%
# person: 25% , motorbike: 27%
# car: 38%
# person: 97%
#
# FPS:39.0 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 26%
# traffic light: 43%
# motorbike: 72%
# motorbike: 40%
# car: 48%
# bicycle: 28%
# person: 98%
# person: 81%
# person: 44%
# person: 30%
# person: 26%
#
# FPS:38.2 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 30%
# bicycle: 38% , motorbike: 45%
# car: 53%
# person: 98%
# person: 82%
# person: 57%
# person: 25%
#
# FPS:38.1 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 28%
# motorbike: 43%
# motorbike: 33%
# car: 59%
# person: 96%
# person: 80%
# person: 42%
# person: 26%
#
# FPS:37.5 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# motorbike: 71%
# car: 50%
# car: 26%
# person: 98%
# person: 70%
# person: 38%
# person: 28%
#
# FPS:37.4 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 34%
# motorbike: 58%
# car: 53%
# car: 44%
# person: 97%
# person: 75%
# person: 42%
# person: 32%
# person: 32%
#
# FPS:37.1 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# motorbike: 37%
# motorbike: 37%
# motorbike: 29%
# car: 56%
# car: 26%
# person: 97%
# person: 77%
# person: 44%
# person: 42%
# person: 39%
# person: 29%
#
# FPS:36.8 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# person: 32% , bicycle: 27% , motorbike: 44%
# motorbike: 37%
# car: 66%
# person: 94%
# person: 69%
# person: 41%
# person: 35%
# person: 34%
#
# FPS:36.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 36%
# bicycle: 61% , motorbike: 42%
# car: 76%
# person: 99%
# person: 58%
# person: 37%
# person: 29%
# person: 27%
#
# FPS:36.3 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 25%
# bicycle: 71% , motorbike: 32%
# car: 80%
# person: 62% , bicycle: 26%
# person: 94%
# person: 27%
#
# FPS:36.0 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 43%
# motorbike: 33%
# car: 82%
# bicycle: 82%
# bicycle: 31%
# person: 97%
# person: 53%
#
# FPS:35.9 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 40%
# car: 81%
# bicycle: 81%
# person: 47% , bicycle: 26%
# person: 95%
# person: 28%
#
# FPS:35.6 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 50%
# bicycle: 65% , motorbike: 51%
# car: 75%
# car: 52%
# person: 94%
# person: 70%
# person: 35%
#
# FPS:35.2 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 67%
# motorbike: 26%
# car: 79%
# car: 47%
# bicycle: 74%
# person: 97%
# person: 90%
#
# FPS:35.0 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 59%
# car: 88%
# car: 29%
# bicycle: 62%
# person: 98%
# person: 96%
# person: 29%
#
# FPS:34.8 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 41%
# car: 83%
# car: 35%
# bicycle: 77%
# person: 94%
# person: 90%
#
# FPS:34.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 25%
# bicycle: 57% , motorbike: 53%
# motorbike: 36%
# car: 89%
# car: 63%
# person: 97%
# person: 97%
#
# FPS:34.5 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 34%
# traffic light: 44%
# traffic light: 26%
# car: 60%
# car: 58%
# bicycle: 68%
# person: 97%
# person: 96%
#
# FPS:34.4 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 49%
# traffic light: 27%
# traffic light: 27%
# motorbike: 29%
# car: 85%
# car: 63%
# bicycle: 79%
# person: 97%
# person: 94%
# person: 31%
#
# FPS:34.3 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 59%
# traffic light: 26%
# car: 85%
# car: 26%
# bicycle: 36%
# bicycle: 27%
# bicycle: 26%
# person: 93%
# person: 91%
# person: 39%
#
# FPS:34.1 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 35%
# traffic light: 42%
# car: 60%
# bicycle: 55%
# bicycle: 42%
# person: 99%
# person: 87%
#
# FPS:33.9 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 48%
# car: 84%
# bicycle: 52%
# bicycle: 28%
# person: 95%
# person: 82%
# person: 27%
# person: 25%
#
# FPS:34.9 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 46%
# traffic light: 49%
# car: 89%
# person: 93%
# person: 86%
#
# FPS:35.2 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 58%
# traffic light: 27%
# car: 72%
# person: 99%
# person: 84%
# person: 29%
#
# FPS:35.1 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 45%
# car: 84%
# person: 98%
# person: 93%
# person: 55%
#
# FPS:34.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 61%
# traffic light: 28%
# car: 77%
# person: 98%
# person: 60%
# person: 33%
# person: 29%
#
# FPS:34.5 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 40%
# car: 88%
# person: 98%
# person: 79%
# person: 35%
# person: 33%
# person: 30%
#
# FPS:34.3 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 53%
# car: 88%
# car: 34%
# person: 97%
# person: 58%
# person: 29%
#
# FPS:34.5 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 41%
# car: 57%
# person: 82%
# person: 56%
# person: 55%
# person: 27%
#
# FPS:35.0 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 59%
# traffic light: 27%
# car: 37%
# person: 85%
# person: 52%
# person: 43%
# person: 29%
#
# FPS:34.8 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 46%
# car: 47%
# person: 85%
# person: 65%
# person: 36%
# person: 32%
#
# FPS:34.9 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# traffic light: 50%
# car: 34%
# car: 30%
# person: 67%
# person: 53%
# person: 48%
# person: 40%
# person: 33%
# person: 26%
#
# FPS:35.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# person: 69%
# person: 63%
# person: 48%
# person: 39%
# person: 39%
#
# FPS:36.3 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# person: 68%
# person: 47%
# person: 45%
# person: 36%
# person: 30%
#
# FPS:36.6 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# person: 36%
# person: 33%
#
# FPS:37.1 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# person: 29%
# person: 26%
#
# FPS:37.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:37.7 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
# person: 40%
# person: 33%
# person: 30%
#
# FPS:38.0 	 AVG_FPS:36.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.3 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# person: 31%
#
# FPS:38.7 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# person: 26%
# person: 25%
#
# FPS:39.4 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.7 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.7 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.7 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# person: 26%
#
# FPS:38.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 74%
# person: 38%
#
# FPS:37.6 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 78%
#
# FPS:37.2 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 78%
#
# FPS:37.4 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 74%
#
# FPS:36.7 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 71%
#
# FPS:36.6 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 78%
# car: 46%
# person: 30%
# person: 29%
#
# FPS:36.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 76%
# car: 34%
#
# FPS:35.9 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 79%
# car: 43%
#
# FPS:35.4 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 82%
# car: 26%
#
# FPS:35.3 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 81%
#
# FPS:34.8 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 79%
#
# FPS:34.7 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 69%
#
# FPS:33.8 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 59%
#
# FPS:33.7 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 69%
#
# FPS:33.3 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 83%
#
# FPS:33.6 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:33.6 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:33.8 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:33.8 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:34.0 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:34.3 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.4 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.6 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:37.0 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:37.3 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.9 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.5 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.8 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.5 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:37.2 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:37.9 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:37.5 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.9 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.5 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:34.9 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:34.8 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:34.5 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:34.4 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:34.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:34.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:33.9 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:33.9 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:33.6 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:34.2 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:33.4 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:33.9 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:33.9 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.0 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.4 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.7 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:37.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:37.7 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.4 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# aeroplane: 34%
#
# FPS:38.6 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.0 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.2 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.5 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.6 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 49%
#
# FPS:40.2 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 71%
#
# FPS:40.2 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 75%
#
# FPS:39.3 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 78%
#
# FPS:38.6 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 68%
#
# FPS:38.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 76%
#
# FPS:37.6 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 92%
#
# FPS:37.2 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 86%
#
# FPS:36.9 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 93%
#
# FPS:36.7 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 92%
#
# FPS:36.3 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.0 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.7 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.9 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.7 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.5 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:37.0 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:37.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:37.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.4 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.5 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.2 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# car: 29%
#
# FPS:35.8 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.3 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.6 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# truck: 49%
#
# FPS:35.3 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 94%
# car: 29%
# car: 26%
#
# FPS:35.7 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 95%
# car: 45%
#
# FPS:35.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 91%
# car: 45%
# car: 34%
# car: 30%
#
# FPS:35.5 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 86%
# car: 41% , truck: 26%
#
# FPS:35.0 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 91%
# car: 82%
#
# FPS:35.3 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 95%
# car: 89%
# car: 29%
# person: 40%
# person: 39%
# person: 32%
# person: 32%
#
# FPS:34.8 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 90%
# car: 88%
# car: 30%
# person: 55%
# person: 37%
# person: 36%
# person: 31%
#
# FPS:35.1 	 AVG_FPS:35.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 91%
# car: 80%
# car: 56%
# person: 62%
# person: 58%
# person: 49%
# person: 35%
# person: 29%
#
# FPS:33.6 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 85%
# car: 76%
# car: 47%
# person: 60%
# person: 39%
# person: 33%
#
# FPS:34.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 93%
# car: 91%
# car: 39%
# person: 44%
# person: 35%
# person: 33%
# person: 27%
#
# FPS:33.8 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 94%
# car: 91%
# car: 57%
# car: 55%
# person: 49%
# person: 45%
# person: 45%
# person: 27%
#
# FPS:34.5 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 82%
# car: 90%
# car: 50%
# car: 42%
# person: 65%
# person: 55%
# person: 42%
# person: 39%
# person: 30%
# person: 26%
#
# FPS:34.1 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 71%
# car: 86%
# car: 41%
# car: 30%
# person: 75%
# person: 61%
# person: 40%
# person: 39%
# person: 37%
#
# FPS:34.5 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 83%
# car: 82%
# car: 72%
# car: 31%
# car: 26%
# bicycle: 38%
# person: 59%
# person: 54%
#
# FPS:34.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 73%
# car: 89%
# car: 62%
# car: 30%
# car: 25%
# person: 29%
#
# FPS:34.7 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 92%
# car: 97%
# car: 54%
# person: 27% , car: 29%
# bicycle: 32%
# person: 49%
# person: 28%
#
# FPS:34.3 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 94%
# car: 92%
# person: 34%
# person: 33%
# person: 31%
# person: 28%
#
# FPS:34.1 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 87%
# car: 67%
# bicycle: 33%
# person: 64%
# person: 57%
# person: 28%
#
# FPS:33.7 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 98%
# truck: 27%
# car: 79%
# car: 61%
# bicycle: 31%
# bicycle: 29%
# person: 42% , bicycle: 29%
# person: 67%
# person: 50%
# person: 47%
# person: 42%
#
# FPS:34.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 98%
# car: 63% , truck: 41%
# person: 74%
# person: 64%
# person: 61%
# person: 50%
#
# FPS:33.8 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 33%
# traffic light: 98%
# car: 85%
# car: 57%
# person: 92%
# person: 46%
# person: 31%
# person: 29%
#
# FPS:34.3 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 95%
# car: 80%
# car: 62%
# bicycle: 30%
# person: 71%
# person: 68%
# person: 65%
# person: 40%
# person: 29%
#
# FPS:33.9 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 94%
# car: 92%
# car: 37%
# bicycle: 45%
# bicycle: 27%
# person: 84%
# person: 61%
# person: 44%
# person: 38%
# person: 37%
# person: 28%
# person: 27%
#
# FPS:34.4 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 96%
# person: 27% , motorbike: 34%
# motorbike: 26%
# car: 87%
# car: 53%
# person: 77%
# person: 64%
# person: 49%
# person: 45%
#
# FPS:34.0 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 94%
# car: 89%
# car: 53%
# person: 82%
# person: 63%
# person: 41%
# person: 36%
#
# FPS:34.4 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 85%
# car: 67% , truck: 43%
# car: 39%
# person: 95%
# person: 47%
# person: 35%
# person: 26%
#
# FPS:34.5 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 95%
# truck: 39%
# car: 78%
# car: 27%
# bicycle: 68%
# bicycle: 45%
# person: 64%
# person: 63%
# person: 45%
# person: 32%
#
# FPS:35.6 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 89%
# bicycle: 32% , motorbike: 25%
# car: 77%
# car: 76%
# bicycle: 27%
# person: 75%
# person: 65%
# person: 44%
# person: 28%
#
# FPS:36.1 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 84%
# motorbike: 48%
# car: 53%
# car: 48%
# bicycle: 37%
# person: 87%
# person: 72%
# person: 71%
# person: 60%
#
# FPS:36.0 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 90%
# car: 82%
# car: 56%
# person: 78%
# person: 33%
# person: 33%
# person: 32%
#
# FPS:36.8 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 90%
# bus: 31%
# motorbike: 53%
# motorbike: 39%
# car: 76%
# bicycle: 51%
# person: 93%
# person: 54%
# person: 45%
#
# FPS:37.4 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 87%
# person: 34% , motorbike: 57%
# motorbike: 28%
# car: 82%
# car: 42%
# person: 82%
# person: 73%
# person: 71%
# person: 25%
#
# FPS:37.7 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 79%
# motorbike: 53%
# car: 82%
# car: 52%
# person: 36%
# person: 92%
# person: 73%
# person: 66%
# person: 30%
#
# FPS:38.1 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 78%
# car: 72% , truck: 27%
# motorbike: 64%
# car: 58%
# person: 87%
# person: 76%
# person: 53%
# person: 29%
#
# FPS:38.5 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 53%
# motorbike: 32%
# car: 53%
# car: 42%
# bicycle: 33%
# person: 74%
# person: 72%
# person: 29%
# person: 27%
#
# FPS:38.9 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 57%
# car: 65% , truck: 36%
# person: 77% , motorbike: 41%
# car: 28%
# person: 36%
# person: 28%
# person: 26%
#
# FPS:39.3 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 44%
# car: 67% , truck: 37%
# person: 39% , motorbike: 64%
# motorbike: 33%
# car: 70%
# car: 36%
# car: 33%
# person: 65%
# person: 60%
# person: 41%
# person: 26%
#
# FPS:39.4 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# motorbike: 52%
# motorbike: 28%
# person: 27%
# car: 74%
# car: 71%
# person: 83%
# person: 36%
#
# FPS:39.6 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# motorbike: 78%
# car: 82%
# car: 70%
# car: 45%
# bicycle: 29%
# person: 88%
# person: 53%
# person: 27%
#
# FPS:39.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# truck: 52%
# car: 54%
# car: 49%
# car: 37%
# person: 85%
# person: 40%
# person: 27%
#
# FPS:38.9 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 67% , truck: 40%
# person: 76% , motorbike: 34%
# motorbike: 28%
# motorbike: 27%
# car: 58%
# car: 51%
# car: 36%
# person: 60%
# person: 37%
# person: 37%
#
# FPS:38.3 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 63% , truck: 48%
# motorbike: 39%
# car: 77%
# car: 69%
# person: 83%
# person: 71%
# person: 37%
#
# FPS:38.3 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 77% , truck: 35%
# motorbike: 45%
# bicycle: 32% , motorbike: 33%
# car: 49%
# person: 85%
# person: 70%
# person: 35%
#
# FPS:37.7 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 87%
# car: 45%
# car: 36%
# car: 30%
# bicycle: 34%
# person: 89%
# person: 36%
# person: 36%
# person: 27%
#
# FPS:36.4 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 92%
# car: 74%
# car: 74%
# bicycle: 25%
# person: 75%
# person: 45%
#
# FPS:36.1 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# motorbike: 29%
# car: 84%
# car: 71%
# car: 48%
# person: 88%
# person: 52%
# person: 41%
# person: 34%
# person: 28%
#
# FPS:36.0 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 86%
# car: 48%
# car: 39%
# person: 87%
# person: 58%
# person: 34%
# person: 28%
#
# FPS:35.4 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# person: 77% , motorbike: 31%
# car: 85%
# car: 55%
# car: 39%
# person: 79%
# person: 39%
# person: 30%
#
# FPS:35.3 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# person: 46% , motorbike: 76%
# car: 81%
# car: 35%
# person: 63%
# person: 57%
# person: 28%
# person: 27%
#
# FPS:35.0 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# person: 28% , motorbike: 76%
# car: 78%
# car: 33%
# person: 75%
# person: 71%
# person: 33%
# person: 29%
#
# FPS:34.4 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# motorbike: 50%
# car: 77%
# person: 76%
# person: 59%
# person: 47%
#
# FPS:34.3 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bicycle: 31% , motorbike: 49%
# car: 72%
# car: 40%
# person: 73%
# person: 66%
# person: 37%
# person: 26%
#
# FPS:34.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bicycle: 26% , motorbike: 46%
# car: 74%
# car: 41%
# person: 81%
# person: 59%
# person: 56%
# person: 39%
#
# FPS:34.0 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bus: 29%
# person: 26% , motorbike: 66%
# motorbike: 46%
# car: 93%
# car: 73%
# person: 46%
# person: 46%
# person: 42%
#
# FPS:34.5 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# person: 58% , motorbike: 51%
# person: 40% , motorbike: 26%
# car: 92%
# car: 58%
# car: 35%
# person: 40%
#
# FPS:34.4 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bus: 49%
# motorbike: 56%
# motorbike: 44%
# car: 79%
# car: 57%
# person: 64%
# person: 40%
# person: 39%
#
# FPS:34.3 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# motorbike: 81%
# motorbike: 67%
# car: 52%
# car: 38%
# person: 80%
# person: 69%
# person: 51%
# person: 41%
# person: 28%
#
# FPS:34.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bus: 58%
# motorbike: 68%
# motorbike: 62%
# car: 76%
# car: 27%
# person: 78%
# person: 77%
# person: 44%
#
# FPS:34.7 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 80% , truck: 31%
# bus: 30%
# motorbike: 41%
# motorbike: 35%
# person: 31% , motorbike: 25%
# car: 34%
# person: 82%
# person: 39%
# person: 29%
# person: 28%
#
# FPS:34.3 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 27% , truck: 27%
# person: 53% , motorbike: 33%
# motorbike: 31%
# car: 79%
# car: 68%
# person: 83%
# person: 60%
# person: 47%
# person: 43%
# person: 41%
#
# FPS:34.8 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bus: 35% , truck: 55%
# car: 58% , truck: 45%
# motorbike: 76%
# person: 69% , motorbike: 41%
# car: 47%
# car: 34%
# person: 96%
# person: 25%
#
# FPS:34.0 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 70% , truck: 38%
# motorbike: 72%
# motorbike: 28%
# car: 48%
# car: 40%
# person: 96%
# person: 75%
# person: 29%
# person: 27%
#
# FPS:35.1 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 76% , truck: 45%
# motorbike: 87%
# motorbike: 61%
# car: 59%
# car: 32%
# person: 97%
# person: 70%
# person: 32%
# person: 27%
#
# FPS:36.0 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 80% , truck: 32%
# motorbike: 67%
# motorbike: 57%
# motorbike: 46%
# car: 52%
# car: 44%
# person: 99%
# person: 52%
# person: 49%
# person: 37%
# person: 30%
# person: 26%
#
# FPS:36.7 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 82% , truck: 35%
# motorbike: 77%
# bicycle: 30% , motorbike: 47%
# motorbike: 33%
# car: 37%
# person: 93%
# person: 51%
# person: 32%
# person: 26%
# person: 26%
#
# FPS:36.6 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 90% , truck: 25%
# motorbike: 59%
# person: 65% , motorbike: 47%
# car: 56%
# car: 32%
# person: 81%
# person: 56%
# person: 35%
#
# FPS:36.4 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 79% , truck: 40%
# motorbike: 67%
# motorbike: 67%
# car: 47%
# person: 96%
# person: 68%
# person: 60%
# person: 40%
# person: 32%
# person: 32%
# person: 31%
#
# FPS:36.6 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 83% , truck: 30%
# motorbike: 80%
# person: 52% , motorbike: 62%
# car: 36%
# person: 94%
#
# FPS:36.8 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 81% , truck: 38%
# bicycle: 33% , motorbike: 50%
# person: 41% , motorbike: 43%
# person: 45% , motorbike: 35%
# car: 29%
# person: 87%
# person: 57%
#
# FPS:37.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 72% , truck: 55%
# person: 61% , motorbike: 63%
# bicycle: 37% , motorbike: 43%
# motorbike: 32%
# car: 62%
# car: 29%
# person: 94%
# person: 46%
# person: 27%
#
# FPS:36.8 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# person: 55% , motorbike: 81%
# motorbike: 41%
# car: 93%
# car: 48%
# car: 39%
# car: 27%
# person: 90%
# person: 48%
#
# FPS:36.1 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# truck: 33%
# car: 86%
# person: 76% , motorbike: 73%
# car: 65%
# bicycle: 41%
# person: 85%
# person: 43%
# person: 29%
#
# FPS:35.7 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# truck: 45%
# car: 82%
# person: 76% , motorbike: 48%
# car: 63%
# car: 28%
# bicycle: 53%
# person: 80%
#
# FPS:35.1 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# person: 51% , motorbike: 51%
# person: 55% , motorbike: 42%
# bicycle: 45% , motorbike: 26%
# car: 83%
# car: 49%
# car: 46%
# car: 35%
# person: 94%
# person: 28%
#
# FPS:34.7 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# person: 75% , motorbike: 62%
# motorbike: 40%
# car: 90%
# car: 65%
# car: 59%
# car: 28%
# bicycle: 61%
# person: 94%
# person: 28%
# person: 27%
#
# FPS:34.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# motorbike: 37%
# person: 86% , motorbike: 32%
# bicycle: 36% , motorbike: 31%
# car: 95%
# car: 56%
# car: 28%
# person: 96%
# person: 43%
# person: 29%
#
# FPS:34.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# truck: 38%
# bicycle: 52% , motorbike: 43%
# motorbike: 27%
# car: 89%
# car: 69%
# car: 29%
# person: 94%
# person: 89%
# person: 29%
# person: 27%
#
# FPS:34.1 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# truck: 33%
# bicycle: 56% , motorbike: 41%
# car: 88%
# car: 30%
# car: 26%
# person: 92%
# person: 73%
# person: 60%
#
# FPS:34.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# truck: 26%
# motorbike: 69%
# motorbike: 59%
# car: 88%
# car: 69%
# person: 94%
# person: 81%
#
# FPS:34.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# motorbike: 80%
# bicycle: 48% , motorbike: 33%
# car: 90%
# car: 48%
# person: 84%
# person: 80%
#
# FPS:34.3 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 84% , truck: 42%
# motorbike: 49%
# motorbike: 30%
# motorbike: 29%
# car: 28%
# person: 85%
# person: 45%
# person: 33%
#
# FPS:35.4 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# truck: 43%
# car: 82%
# motorbike: 65%
# motorbike: 63%
# car: 66%
# car: 47%
# person: 78%
# person: 76%
# person: 44%
# person: 25%
#
# FPS:36.1 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# truck: 41%
# motorbike: 82%
# motorbike: 31%
# car: 83%
# car: 58%
# car: 42%
# person: 87%
# person: 80%
#
# FPS:36.6 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 70% , truck: 27%
# bicycle: 30% , motorbike: 30%
# car: 46%
# person: 90%
# person: 44%
# person: 26%
#
# FPS:37.1 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# motorbike: 55%
# motorbike: 36%
# person: 79%
# person: 67%
# person: 27%
#
# FPS:37.5 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bicycle: 34% , motorbike: 42%
# bicycle: 39%
# person: 77%
# person: 52%
# person: 42%
# person: 32%
#
# FPS:37.3 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bicycle: 41% , motorbike: 37%
# person: 86%
# person: 56%
# person: 37%
#
# FPS:37.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 27%
# bicycle: 27% , motorbike: 67%
# car: 31%
# person: 66%
# person: 65%
# person: 34%
#
# FPS:36.8 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# motorbike: 77%
# motorbike: 26%
# person: 82%
# person: 51%
#
# FPS:36.4 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bicycle: 33% , motorbike: 35%
# person: 84%
# person: 25%
#
# FPS:36.1 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# motorbike: 60%
# motorbike: 39%
# person: 74%
# person: 60%
#
# FPS:35.8 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bicycle: 79%
# bicycle: 54%
# person: 91%
# person: 26%
#
# FPS:36.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 31%
# chair: 55%
# chair: 42%
# bicycle: 35% , motorbike: 45%
# bicycle: 47% , motorbike: 39%
# person: 82%
# person: 48%
#
# FPS:36.3 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bicycle: 31% , motorbike: 54%
# car: 29%
# bicycle: 68%
# person: 93%
#
# FPS:37.0 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bicycle: 34% , motorbike: 42%
# bicycle: 28%
# person: 92%
#
# FPS:37.7 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 26%
# bicycle: 63%
# person: 82%
# person: 52%
#
# FPS:36.8 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 30%
# person: 73% , motorbike: 27%
# bicycle: 53%
#
# FPS:36.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# car: 36%
# person: 61%
# person: 47%
#
# FPS:35.8 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# person: 82% , motorbike: 33%
# bicycle: 31%
#
# FPS:35.3 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 40%
# car: 38%
# bicycle: 44%
# person: 64%
#
# FPS:34.9 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 25%
# bicycle: 65%
# person: 80%
# person: 25%
#
# FPS:34.7 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 28%
# bicycle: 60%
# person: 58%
#
# FPS:34.4 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 35%
# traffic light: 25%
# car: 41%
# bicycle: 64%
# person: 56%
#
# FPS:35.5 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 30%
# bicycle: 57%
# person: 78%
# person: 26%
#
# FPS:34.5 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# traffic light: 35%
# bicycle: 38%
# person: 56%
#
# FPS:34.7 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bicycle: 31%
# person: 35%
#
# FPS:34.2 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bicycle: 29% , motorbike: 38%
#
# FPS:33.8 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bicycle: 29% , motorbike: 26%
#
# FPS:33.6 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 30%
# pottedplant: 25%
# bicycle: 32%
#
# FPS:33.6 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 26%
# car: 38%
# bicycle: 53%
#
# FPS:33.5 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 29%
# bicycle: 29%
#
# FPS:33.4 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# bicycle: 26%
#
# FPS:32.9 	 AVG_FPS:35.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 27%
# bicycle: 34%
#
# FPS:31.8 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 25%
# chair: 36%
#
# FPS:32.0 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 31%
# pottedplant: 30%
# chair: 30%
# chair: 28%
# bench: 44%
#
# FPS:32.2 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 45%
# pottedplant: 39%
#
# FPS:32.2 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 39%
# pottedplant: 29%
# pottedplant: 28%
# pottedplant: 27%
#
# FPS:32.3 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 46%
# pottedplant: 33%
# pottedplant: 29%
# bench: 39% , chair: 48%
#
# FPS:32.3 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 44%
# bench: 37% , chair: 39%
#
# FPS:32.4 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 39%
# pottedplant: 33%
# pottedplant: 29%
#
# FPS:32.4 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 37%
# pottedplant: 28%
# pottedplant: 26%
#
# FPS:32.5 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 30%
# pottedplant: 27%
# chair: 36%
# traffic light: 26%
# person: 26%
#
# FPS:32.4 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 37%
# pottedplant: 31%
# pottedplant: 31%
# pottedplant: 27%
# pottedplant: 27%
# pottedplant: 27%
# pottedplant: 25%
#
# FPS:32.5 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 29%
#
# FPS:32.1 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 41%
# car: 52%
#
# FPS:31.8 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 41%
# pottedplant: 34%
# pottedplant: 25%
#
# FPS:31.8 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 31%
# traffic light: 32%
#
# FPS:32.3 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 34%
# car: 32%
# person: 44%
# person: 29%
#
# FPS:32.4 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 37%
#
# FPS:32.9 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 64%
#
# FPS:32.9 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 29%
# pottedplant: 27%
# stop sign: 27%
#
# FPS:33.2 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# stop sign: 31%
#
# FPS:33.1 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 61%
# car: 52%
#
# FPS:33.7 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 49%
# car: 36%
# person: 31%
#
# FPS:32.7 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 80%
# car: 36%
#
# FPS:32.9 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# stop sign: 41%
# car: 57%
# car: 36%
#
# FPS:34.2 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# stop sign: 30%
# car: 67%
# car: 40%
# person: 28%
#
# FPS:34.8 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.5 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 40%
# car: 30%
# person: 44%
#
# FPS:36.1 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 64%
# car: 41%
# person: 54%
#
# FPS:36.5 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 28%
# car: 27%
#
# FPS:36.9 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 39%
# person: 26%
#
# FPS:37.5 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 52%
# car: 33%
# person: 35%
#
# FPS:38.0 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 54%
# car: 27%
#
# FPS:38.2 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 59%
# car: 35%
#
# FPS:38.5 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 48%
# car: 38%
# person: 25%
#
# FPS:38.8 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# person: 26%
#
# FPS:39.1 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 30%
#
# FPS:39.2 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# stop sign: 26%
# car: 27%
#
# FPS:39.3 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.6 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 26%
#
# FPS:39.9 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 82%
#
# FPS:38.1 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 85%
#
# FPS:38.8 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 27%
# car: 81%
# person: 27%
#
# FPS:39.3 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# stop sign: 30%
# traffic light: 33%
# car: 76%
# person: 70%
#
# FPS:39.6 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# stop sign: 30%
# traffic light: 40%
# car: 77%
# car: 26%
# person: 58%
#
# FPS:39.7 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 34%
# car: 77%
# person: 46%
#
# FPS:39.4 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 28%
# car: 69%
# person: 37%
#
# FPS:38.6 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 60%
#
# FPS:38.7 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 72%
#
# FPS:38.2 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 29%
# car: 72%
#
# FPS:38.1 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 51%
#
# FPS:37.5 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 31%
# car: 60%
#
# FPS:37.5 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 54%
# car: 54%
# person: 36%
#
# FPS:37.0 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 40%
# car: 53%
# car: 31%
#
# FPS:37.2 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 50%
#
# FPS:36.8 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# stop sign: 31%
# car: 25%
#
# FPS:36.9 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# stop sign: 27%
#
# FPS:36.5 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# stop sign: 37%
#
# FPS:36.7 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 38%
#
# FPS:36.1 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 46%
#
# FPS:36.2 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# stop sign: 31%
# traffic light: 38%
#
# FPS:34.9 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 42%
# car: 29%
#
# FPS:35.3 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 46%
# car: 32%
#
# FPS:35.0 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 36%
#
# FPS:35.4 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# stop sign: 25%
# traffic light: 25%
# car: 27%
#
# FPS:35.1 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 32%
#
# FPS:35.3 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.0 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.3 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.1 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 36%
#
# FPS:34.4 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 46%
#
# FPS:35.4 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 50%
#
# FPS:36.3 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 60%
#
# FPS:36.8 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 53%
#
# FPS:37.1 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 74%
#
# FPS:37.6 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 61%
#
# FPS:38.0 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 47%
# car: 31%
#
# FPS:38.4 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 64%
# car: 33%
#
# FPS:38.7 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 63%
#
# FPS:39.0 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 79%
#
# FPS:39.2 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 91%
# person: 29%
#
# FPS:39.5 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 86%
# person: 30%
#
# FPS:39.6 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 81%
#
# FPS:39.9 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 82%
#
# FPS:40.0 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 90%
#
# FPS:40.2 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 79%
#
# FPS:40.2 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 75%
#
# FPS:40.3 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 73%
# car: 28%
# person: 28%
#
# FPS:40.3 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 57%
# person: 42%
#
# FPS:40.4 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 48%
# person: 30%
#
# FPS:40.3 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 59%
#
# FPS:40.3 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 65% , truck: 26%
#
# FPS:40.0 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 78%
#
# FPS:39.2 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 78% , truck: 28%
#
# FPS:38.6 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 79%
#
# FPS:38.8 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 58% , truck: 41%
#
# FPS:38.8 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 85%
#
# FPS:39.1 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 89%
#
# FPS:38.8 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 88%
#
# FPS:38.4 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 83%
#
# FPS:38.5 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 88%
#
# FPS:38.4 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# traffic light: 43%
# car: 81% , truck: 28%
#
# FPS:38.3 	 AVG_FPS:34.7
#
#  cvWriteFrame
# Objects:
#
# car: 74% , truck: 40%
#
# FPS:38.2 	 AVG_FPS:34.7
#
#  cvWriteFrame

# %%
# download the video with detections shown
download('results.avi')
